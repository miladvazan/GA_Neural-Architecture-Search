# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   On_Black="\033[40m"
   On_Red="\033[41m"
   On_Green="\033[42m"
   On_Yellow="\033[43m"
   On_Blue="\033[44m"
   On_Purple="\033[45m"
   On_Cyan="\033[46m"
   On_White="\033[47m"
   On_IBlue="\033[0;104m"
   END = '\033[0m'

# %%
import random
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load CIFAR-10 dataset

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)
input_shape = x_train.shape[1:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 72s 0us/step

# %% [markdown]
# # Define the search space for NAS

# %%
search_space = {
    'num_conv_layers': [ConV for ConV in range(1, 7)],
    'num_filters': [num_filer_ for num_filer_ in range(2, 16)],
    'num_dense_units': [num_dense_units_ for num_dense_units_ in range(128, 1024)],
    'kernel_size': [kernel_size_ for kernel_size_ in range(2, 7)],
    'pool_size': [pool_size_ for pool_size_ in range(2, 5)],
    #'learning_rate': [0.0001, 0.001, 0.01, 0.1]
}

# %% [markdown]
# # Generate an initial population of neural architectures

# %%
def generate_population(size):
    population = []
    print(color.On_Purple+"Initial population of neural architectures--------------------------------------------------------------------------"+color.END)
    Count_for_pop = 1
    for _ in range(size):
        architecture = {}
        for param, choices in search_space.items():
            architecture[param] = random.choice(choices)
        population.append(architecture)
        print("Population:", Count_for_pop, architecture)
        Count_for_pop += 1
    print(color.On_Purple+"--------------------------------------------------------------------------------------------------------------------"+color.END)
    return population

# %% [markdown]
# # Evaluate the architectures in the population

# %%
epochs = 5
batch_size = 128
def evaluate_architecture(architecture, X_val=x_val, Y_val=y_val ):
    model = Sequential()
    # Add convolutional layers
    for _ in range(int(architecture['num_conv_layers'])):
        model.add(Conv2D(int(architecture['num_filters']), (int(architecture['kernel_size']),
                                                             int(architecture['kernel_size'])),
                         activation='relu', padding='same', input_shape=input_shape))
        model.add(MaxPooling2D(pool_size=(int(architecture['pool_size']), int(architecture['pool_size'])), padding='same'))

    model.add(Flatten())

    # Add dense layers
    model.add(Dense(architecture['num_dense_units'], activation='relu'))

    # Output layer
    model.add(Dense(10, activation='softmax'))

    # Compile the model
    optimizer = Adam()
    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer=optimizer,
                  metrics=['accuracy'])

    # Train the model
    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=0)

    # Evaluate the model on the validation set
    _, accuracy = model.evaluate(X_val, Y_val, verbose=0)
    return accuracy

# %% [markdown]
# # Select parents

# %%
def select_parents(population, num_parents):
    print(color.GREEN+"Select parents for reproduction"+color.END)
    parents = random.sample(population, num_parents)
    for item in parents:
        print(item)
    return parents

# Select parents for reproduction using *******roulette wheel selection*********
#def select_parents(population, num_parents):
    #print("Select parents for reproduction")
    #fitness_values = [individual['fitness'] for individual in population]
    #sum_fitness = sum(fitness_values)
    #probabilities = [fitness / sum_fitness for fitness in fitness_values]
    #parents = random.choices(population, probabilities, k=num_parents)
    #for item in parents:
        #print(item)
    #return parents

# %% [markdown]
# # Generate offspring architectures using genetic operators

# %%
def generate_offspring(parents, num_offspring, mutation_rate):
    print(color.GREEN+"Generate offspring architectures using genetic operators:"+color.END)
    offspring = []
    OFF_Count = 1
    for _ in range(num_offspring):
        parent1, parent2 = random.choices(parents, k=2)
        while parent1 == parent2:  # Repeat selection if parent1 and parent2 are the same
          parent1, parent2 = random.choices(parents, k=2)
        print(color.On_IBlue+"random choices parent1 and parent2 for offspring:"+color.END, OFF_Count)
        OFF_Count +=1
        print("parent1", parent1)
        print("parent2", parent2)
        child = {}
        for param in search_space.keys():
            parent1_binary = bin(int(parent1[param]))[2:]  # Convert integer to binary
            parent2_binary = bin(int(parent2[param]))[2:]  # Convert integer to binary

            # Add necessary leading zeros if required
            parent1_binary = '0' * (len(bin(max(int(parent1[param]), int(parent2[param])))[2:]) - len(parent1_binary)) + parent1_binary
            parent2_binary = '0' * (len(bin(max(int(parent1[param]), int(parent2[param])))[2:]) - len(parent2_binary)) + parent2_binary

            child_binary = ''
            for i in range(len(parent1_binary)):
                if random.random() < 0.3:
                    child_binary += parent1_binary[i]
                else:
                    child_binary += parent2_binary[i]

            child[param] = int(child_binary, 2)  # Convert binary to integer
            if random.random() < mutation_rate:
                mutated_value = random.choice(search_space[param])
                child[param] = mutated_value
                print(color.RED +color.BOLD+f"Mutated {param} to {mutated_value}"+color.END)
            elif child[param] == 0:
                child[param] = parent2[param]  # Replace the value with the parent's value
        offspring.append(child)

    Of_n = 1
    print(color.On_Red+"----------------------------------------------------------------------------------------------------------------------"+color.END)
    for item_4 in offspring:
        print(color.BLUE +color.BOLD+f"Offsprings {Of_n}: {item_4}"+color.END)
        Of_n += 1

    return offspring

# %% [markdown]
# # Evaluate the offspring architectures

# %%
def evaluate_offspring(offspring):
    print(color.On_Red+"----------------------------------------------------------------------------------------------------------------------"+color.END)
    Ch = 1
    for child in offspring:
        child['fitness'] = evaluate_architecture(child)
        print(color.GREEN +color.BOLD+f"child fitness {Ch}:"+color.END, child['fitness'])
        print(color.GREEN+"-------------------------------------------------------"+color.END)
        Ch +=1

# %% [markdown]
# # Combine parents, offspring, and top performers

# %%
def combine_population(offspring):
    population = offspring #parents + top performers
    for item_3 in population:
      print(item_3)
    return population

# %% [markdown]
# # Define the termination criterion

# %%
def termination_criterion(generation, max_generations):
    return generation >= max_generations

# %% [markdown]
# # NAS with genetic algorithm

# %%
def nas_ga(population_size, num_parents, num_offspring, num_generations, mutation_rate):
    population = generate_population(population_size)
    NN = 1
    for individual in population:
        individual['fitness'] = evaluate_architecture(individual)
        print(color.GREEN +color.BOLD+"individual:"+color.END, NN ,color.DARKCYAN +color.BOLD+"-------->> individual fitness:"+color.END, individual['fitness'])
        NN += 1
    for generation in range(num_generations):
        print(color.On_Purple+"********************************generation:"+color.END, generation+1, color.On_Purple+"**********************************************"+color.END)
        parents = select_parents(population, num_parents)
        offspring = generate_offspring(parents, num_offspring, mutation_rate)
        evaluate_offspring(offspring)
        population = combine_population(offspring)
        if termination_criterion(generation, num_generations):
            break

    best_architecture = max(population, key=lambda x: x['fitness'])
    print("Best architecture:", best_architecture)
    print(color.On_Purple+"evaluate test datse with Best architecture:"+color.END, evaluate_architecture(best_architecture, x_test, y_test))
    return best_architecture

# %% [markdown]
# # Run NAS with genetic algorithm

# %%
population_size = 10
num_parents = 5
num_generations = 10
mutation_rate = 0.2
best_architecture = nas_ga(population_size=population_size, num_parents=num_parents,
                           num_offspring=population_size, num_generations=num_generations, mutation_rate = mutation_rate)
# Out:
# Initial population of neural architectures--------------------------------------------------------------------------
# Population: 1 {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 3}
# Population: 2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 915, 'kernel_size': 2, 'pool_size': 3}
# Population: 3 {'num_conv_layers': 1, 'num_filters': 15, 'num_dense_units': 830, 'kernel_size': 5, 'pool_size': 4}
# Population: 4 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3}
# Population: 5 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 774, 'kernel_size': 3, 'pool_size': 2}
# Population: 6 {'num_conv_layers': 1, 'num_filters': 15, 'num_dense_units': 823, 'kernel_size': 5, 'pool_size': 2}
# Population: 7 {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 514, 'kernel_size': 2, 'pool_size': 4}
# Population: 8 {'num_conv_layers': 6, 'num_filters': 4, 'num_dense_units': 714, 'kernel_size': 3, 'pool_size': 2}
# Population: 9 {'num_conv_layers': 5, 'num_filters': 10, 'num_dense_units': 823, 'kernel_size': 6, 'pool_size': 3}
# Population: 10 {'num_conv_layers': 1, 'num_filters': 14, 'num_dense_units': 542, 'kernel_size': 4, 'pool_size': 3}
# --------------------------------------------------------------------------------------------------------------------
# individual: 1 -------->> individual fitness: 0.5446000099182129
# individual: 2 -------->> individual fitness: 0.18330000340938568
# individual: 3 -------->> individual fitness: 0.3707999885082245
# individual: 4 -------->> individual fitness: 0.3580000102519989
# individual: 5 -------->> individual fitness: 0.3675999939441681
# individual: 6 -------->> individual fitness: 0.32670000195503235
# individual: 7 -------->> individual fitness: 0.3391999900341034
# individual: 8 -------->> individual fitness: 0.30570000410079956
# individual: 9 -------->> individual fitness: 0.4684999883174896
# individual: 10 -------->> individual fitness: 0.41019999980926514
# ********************************generation: 1 **********************************************
# Select parents for reproduction
# {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.3580000102519989}
# {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 774, 'kernel_size': 3, 'pool_size': 2, 'fitness': 0.3675999939441681}
# {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 3, 'fitness': 0.5446000099182129}
# {'num_conv_layers': 1, 'num_filters': 15, 'num_dense_units': 830, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.3707999885082245}
# {'num_conv_layers': 6, 'num_filters': 4, 'num_dense_units': 714, 'kernel_size': 3, 'pool_size': 2, 'fitness': 0.30570000410079956}
# Generate offspring architectures using genetic operators:
# random choices parent1 and parent2 for offspring: 1
# parent1 {'num_conv_layers': 6, 'num_filters': 4, 'num_dense_units': 714, 'kernel_size': 3, 'pool_size': 2, 'fitness': 0.30570000410079956}
# parent2 {'num_conv_layers': 1, 'num_filters': 15, 'num_dense_units': 830, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.3707999885082245}
# Mutated kernel_size to 4
# random choices parent1 and parent2 for offspring: 2
# parent1 {'num_conv_layers': 1, 'num_filters': 15, 'num_dense_units': 830, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.3707999885082245}
# parent2 {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 3, 'fitness': 0.5446000099182129}
# Mutated num_dense_units to 486
# random choices parent1 and parent2 for offspring: 3
# parent1 {'num_conv_layers': 1, 'num_filters': 15, 'num_dense_units': 830, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.3707999885082245}
# parent2 {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 3, 'fitness': 0.5446000099182129}
# Mutated num_filters to 5
# random choices parent1 and parent2 for offspring: 4
# parent1 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.3580000102519989}
# parent2 {'num_conv_layers': 6, 'num_filters': 4, 'num_dense_units': 714, 'kernel_size': 3, 'pool_size': 2, 'fitness': 0.30570000410079956}
# random choices parent1 and parent2 for offspring: 5
# parent1 {'num_conv_layers': 6, 'num_filters': 4, 'num_dense_units': 714, 'kernel_size': 3, 'pool_size': 2, 'fitness': 0.30570000410079956}
# parent2 {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 3, 'fitness': 0.5446000099182129}
# random choices parent1 and parent2 for offspring: 6
# parent1 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 774, 'kernel_size': 3, 'pool_size': 2, 'fitness': 0.3675999939441681}
# parent2 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.3580000102519989}
# Mutated num_conv_layers to 3
# Mutated pool_size to 2
# random choices parent1 and parent2 for offspring: 7
# parent1 {'num_conv_layers': 6, 'num_filters': 4, 'num_dense_units': 714, 'kernel_size': 3, 'pool_size': 2, 'fitness': 0.30570000410079956}
# parent2 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.3580000102519989}
# Mutated kernel_size to 6
# random choices parent1 and parent2 for offspring: 8
# parent1 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.3580000102519989}
# parent2 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 774, 'kernel_size': 3, 'pool_size': 2, 'fitness': 0.3675999939441681}
# Mutated num_filters to 15
# random choices parent1 and parent2 for offspring: 9
# parent1 {'num_conv_layers': 6, 'num_filters': 4, 'num_dense_units': 714, 'kernel_size': 3, 'pool_size': 2, 'fitness': 0.30570000410079956}
# parent2 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.3580000102519989}
# Mutated num_conv_layers to 1
# Mutated pool_size to 4
# random choices parent1 and parent2 for offspring: 10
# parent1 {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 3, 'fitness': 0.5446000099182129}
# parent2 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.3580000102519989}
# Mutated num_conv_layers to 6
# Mutated pool_size to 3
# ----------------------------------------------------------------------------------------------------------------------
# Offsprings 1: {'num_conv_layers': 4, 'num_filters': 15, 'num_dense_units': 862, 'kernel_size': 4, 'pool_size': 4}
# Offsprings 2: {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 486, 'kernel_size': 4, 'pool_size': 3}
# Offsprings 3: {'num_conv_layers': 1, 'num_filters': 5, 'num_dense_units': 578, 'kernel_size': 5, 'pool_size': 1}
# Offsprings 4: {'num_conv_layers': 7, 'num_filters': 4, 'num_dense_units': 522, 'kernel_size': 7, 'pool_size': 2}
# Offsprings 5: {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 2}
# Offsprings 6: {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 7: {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 898, 'kernel_size': 6, 'pool_size': 2}
# Offsprings 8: {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 774, 'kernel_size': 5, 'pool_size': 3}
# Offsprings 9: {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 862, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 10: {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3}
# ----------------------------------------------------------------------------------------------------------------------
# child fitness 1: 0.5034999847412109
# -------------------------------------------------------
# child fitness 2: 0.44339999556541443
# -------------------------------------------------------
# child fitness 3: 0.32580000162124634
# -------------------------------------------------------
# child fitness 4: 0.3328999876976013
# -------------------------------------------------------
# child fitness 5: 0.5360999703407288
# -------------------------------------------------------
# child fitness 6: 0.47999998927116394
# -------------------------------------------------------
# child fitness 7: 0.4887999892234802
# -------------------------------------------------------
# child fitness 8: 0.5252000093460083
# -------------------------------------------------------
# child fitness 9: 0.35350000858306885
# -------------------------------------------------------
# child fitness 10: 0.47609999775886536
# -------------------------------------------------------
# {'num_conv_layers': 4, 'num_filters': 15, 'num_dense_units': 862, 'kernel_size': 4, 'pool_size': 4, 'fitness': 0.5034999847412109}
# {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 486, 'kernel_size': 4, 'pool_size': 3, 'fitness': 0.44339999556541443}
# {'num_conv_layers': 1, 'num_filters': 5, 'num_dense_units': 578, 'kernel_size': 5, 'pool_size': 1, 'fitness': 0.32580000162124634}
# {'num_conv_layers': 7, 'num_filters': 4, 'num_dense_units': 522, 'kernel_size': 7, 'pool_size': 2, 'fitness': 0.3328999876976013}
# {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.5360999703407288}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.47999998927116394}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 898, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4887999892234802}
# {'num_conv_layers': 3, 'num_filters': 15, 'num_dense_units': 774, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.5252000093460083}
# {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 862, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.35350000858306885}
# {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.47609999775886536}
# ********************************generation: 2 **********************************************
# Select parents for reproduction
# {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.5360999703407288}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.47999998927116394}
# {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.47609999775886536}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 898, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4887999892234802}
# {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 862, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.35350000858306885}
# Generate offspring architectures using genetic operators:
# random choices parent1 and parent2 for offspring: 1
# parent1 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 862, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.35350000858306885}
# parent2 {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.47609999775886536}
# Mutated num_filters to 7
# random choices parent1 and parent2 for offspring: 2
# parent1 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 898, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4887999892234802}
# parent2 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 862, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.35350000858306885}
# Mutated num_dense_units to 601
# random choices parent1 and parent2 for offspring: 3
# parent1 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.47999998927116394}
# parent2 {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.47609999775886536}
# Mutated pool_size to 4
# random choices parent1 and parent2 for offspring: 4
# parent1 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 898, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4887999892234802}
# parent2 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.47999998927116394}
# random choices parent1 and parent2 for offspring: 5
# parent1 {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.5360999703407288}
# parent2 {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 862, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.35350000858306885}
# Mutated kernel_size to 3
# random choices parent1 and parent2 for offspring: 6
# parent1 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.47999998927116394}
# parent2 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 898, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4887999892234802}
# Mutated num_conv_layers to 2
# random choices parent1 and parent2 for offspring: 7
# parent1 {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.5360999703407288}
# parent2 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.47999998927116394}
# Mutated num_filters to 13
# random choices parent1 and parent2 for offspring: 8
# parent1 {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.5360999703407288}
# parent2 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 898, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4887999892234802}
# Mutated num_conv_layers to 2
# Mutated num_dense_units to 682
# random choices parent1 and parent2 for offspring: 9
# parent1 {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.5360999703407288}
# parent2 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.47999998927116394}
# Mutated num_filters to 13
# random choices parent1 and parent2 for offspring: 10
# parent1 {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 578, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.5360999703407288}
# parent2 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.47999998927116394}
# Mutated num_filters to 3
# ----------------------------------------------------------------------------------------------------------------------
# Offsprings 1: {'num_conv_layers': 6, 'num_filters': 7, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 2: {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 601, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 3: {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 4: {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 934, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 5: {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 858, 'kernel_size': 3, 'pool_size': 4}
# Offsprings 6: {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 786, 'kernel_size': 6, 'pool_size': 2}
# Offsprings 7: {'num_conv_layers': 3, 'num_filters': 13, 'num_dense_units': 774, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 8: {'num_conv_layers': 2, 'num_filters': 8, 'num_dense_units': 682, 'kernel_size': 6, 'pool_size': 2}
# Offsprings 9: {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 790, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 10: {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2}
# ----------------------------------------------------------------------------------------------------------------------
# child fitness 1: 0.4526999890804291
# -------------------------------------------------------
# child fitness 2: 0.35089999437332153
# -------------------------------------------------------
# child fitness 3: 0.4584999978542328
# -------------------------------------------------------
# child fitness 4: 0.49950000643730164
# -------------------------------------------------------
# child fitness 5: 0.43619999289512634
# -------------------------------------------------------
# child fitness 6: 0.4916999936103821
# -------------------------------------------------------
# child fitness 7: 0.4787999987602234
# -------------------------------------------------------
# child fitness 8: 0.35839998722076416
# -------------------------------------------------------
# child fitness 9: 0.42829999327659607
# -------------------------------------------------------
# child fitness 10: 0.420199990272522
# -------------------------------------------------------
# {'num_conv_layers': 6, 'num_filters': 7, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4526999890804291}
# {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 601, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.35089999437332153}
# {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4584999978542328}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 934, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.49950000643730164}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 858, 'kernel_size': 3, 'pool_size': 4, 'fitness': 0.43619999289512634}
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 786, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4916999936103821}
# {'num_conv_layers': 3, 'num_filters': 13, 'num_dense_units': 774, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4787999987602234}
# {'num_conv_layers': 2, 'num_filters': 8, 'num_dense_units': 682, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.35839998722076416}
# {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 790, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.42829999327659607}
# {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.420199990272522}
# ********************************generation: 3 **********************************************
# Select parents for reproduction
# {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.420199990272522}
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 786, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4916999936103821}
# {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4584999978542328}
# {'num_conv_layers': 6, 'num_filters': 7, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4526999890804291}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 934, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.49950000643730164}
# Generate offspring architectures using genetic operators:
# random choices parent1 and parent2 for offspring: 1
# parent1 {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4584999978542328}
# parent2 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 786, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4916999936103821}
# Mutated kernel_size to 4
# random choices parent1 and parent2 for offspring: 2
# parent1 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 786, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4916999936103821}
# parent2 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 934, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.49950000643730164}
# Mutated kernel_size to 5
# random choices parent1 and parent2 for offspring: 3
# parent1 {'num_conv_layers': 6, 'num_filters': 7, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4526999890804291}
# parent2 {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.420199990272522}
# Mutated num_dense_units to 351
# random choices parent1 and parent2 for offspring: 4
# parent1 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 786, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4916999936103821}
# parent2 {'num_conv_layers': 6, 'num_filters': 7, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4526999890804291}
# random choices parent1 and parent2 for offspring: 5
# parent1 {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.420199990272522}
# parent2 {'num_conv_layers': 6, 'num_filters': 7, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4526999890804291}
# Mutated num_conv_layers to 4
# random choices parent1 and parent2 for offspring: 6
# parent1 {'num_conv_layers': 6, 'num_filters': 7, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4526999890804291}
# parent2 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 786, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4916999936103821}
# Mutated num_filters to 10
# Mutated num_dense_units to 237
# random choices parent1 and parent2 for offspring: 7
# parent1 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 934, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.49950000643730164}
# parent2 {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.420199990272522}
# Mutated num_conv_layers to 1
# Mutated num_dense_units to 474
# random choices parent1 and parent2 for offspring: 8
# parent1 {'num_conv_layers': 6, 'num_filters': 7, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4526999890804291}
# parent2 {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.420199990272522}
# Mutated num_filters to 2
# random choices parent1 and parent2 for offspring: 9
# parent1 {'num_conv_layers': 6, 'num_filters': 7, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4526999890804291}
# parent2 {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4584999978542328}
# Mutated num_dense_units to 753
# Mutated pool_size to 2
# random choices parent1 and parent2 for offspring: 10
# parent1 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 934, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.49950000643730164}
# parent2 {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.420199990272522}
# Mutated num_dense_units to 558
# ----------------------------------------------------------------------------------------------------------------------
# Offsprings 1: {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 818, 'kernel_size': 4, 'pool_size': 2}
# Offsprings 2: {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 930, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 3: {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 351, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 4: {'num_conv_layers': 6, 'num_filters': 3, 'num_dense_units': 822, 'kernel_size': 6, 'pool_size': 2}
# Offsprings 5: {'num_conv_layers': 4, 'num_filters': 3, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 6: {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 237, 'kernel_size': 6, 'pool_size': 2}
# Offsprings 7: {'num_conv_layers': 1, 'num_filters': 3, 'num_dense_units': 474, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 8: {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 9: {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 10: {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 558, 'kernel_size': 5, 'pool_size': 2}
# ----------------------------------------------------------------------------------------------------------------------
# child fitness 1: 0.4936999976634979
# -------------------------------------------------------
# child fitness 2: 0.4544000029563904
# -------------------------------------------------------
# child fitness 3: 0.3720000088214874
# -------------------------------------------------------
# child fitness 4: 0.35420000553131104
# -------------------------------------------------------
# child fitness 5: 0.40119999647140503
# -------------------------------------------------------
# child fitness 6: 0.4169999957084656
# -------------------------------------------------------
# child fitness 7: 0.26080000400543213
# -------------------------------------------------------
# child fitness 8: 0.20749999582767487
# -------------------------------------------------------
# child fitness 9: 0.20970000326633453
# -------------------------------------------------------
# child fitness 10: 0.3797000050544739
# -------------------------------------------------------
# {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 818, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.4936999976634979}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 930, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4544000029563904}
# {'num_conv_layers': 3, 'num_filters': 3, 'num_dense_units': 351, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3720000088214874}
# {'num_conv_layers': 6, 'num_filters': 3, 'num_dense_units': 822, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.35420000553131104}
# {'num_conv_layers': 4, 'num_filters': 3, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.40119999647140503}
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 237, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4169999957084656}
# {'num_conv_layers': 1, 'num_filters': 3, 'num_dense_units': 474, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.26080000400543213}
# {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 886, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.20749999582767487}
# {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.20970000326633453}
# {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 558, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3797000050544739}
# ********************************generation: 4 **********************************************
# Select parents for reproduction
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 237, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4169999957084656}
# {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 558, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3797000050544739}
# {'num_conv_layers': 4, 'num_filters': 3, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.40119999647140503}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 930, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4544000029563904}
# {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.20970000326633453}
# Generate offspring architectures using genetic operators:
# random choices parent1 and parent2 for offspring: 1
# parent1 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 930, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4544000029563904}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.20970000326633453}
# Mutated num_filters to 8
# random choices parent1 and parent2 for offspring: 2
# parent1 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 237, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4169999957084656}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.20970000326633453}
# random choices parent1 and parent2 for offspring: 3
# parent1 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.20970000326633453}
# parent2 {'num_conv_layers': 4, 'num_filters': 3, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.40119999647140503}
# Mutated kernel_size to 3
# Mutated pool_size to 3
# random choices parent1 and parent2 for offspring: 4
# parent1 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 237, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4169999957084656}
# parent2 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 558, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3797000050544739}
# Mutated kernel_size to 6
# random choices parent1 and parent2 for offspring: 5
# parent1 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 558, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3797000050544739}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.20970000326633453}
# Mutated num_dense_units to 995
# random choices parent1 and parent2 for offspring: 6
# parent1 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 558, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3797000050544739}
# parent2 {'num_conv_layers': 4, 'num_filters': 3, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.40119999647140503}
# Mutated pool_size to 3
# random choices parent1 and parent2 for offspring: 7
# parent1 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.20970000326633453}
# parent2 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 558, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3797000050544739}
# Mutated pool_size to 2
# random choices parent1 and parent2 for offspring: 8
# parent1 {'num_conv_layers': 4, 'num_filters': 3, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.40119999647140503}
# parent2 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 237, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4169999957084656}
# Mutated num_filters to 10
# Mutated kernel_size to 4
# Mutated pool_size to 3
# random choices parent1 and parent2 for offspring: 9
# parent1 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 558, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3797000050544739}
# parent2 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 237, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4169999957084656}
# Mutated num_conv_layers to 6
# Mutated kernel_size to 5
# random choices parent1 and parent2 for offspring: 10
# parent1 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 930, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4544000029563904}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.20970000326633453}
# ----------------------------------------------------------------------------------------------------------------------
# Offsprings 1: {'num_conv_layers': 6, 'num_filters': 8, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 2: {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 3: {'num_conv_layers': 4, 'num_filters': 3, 'num_dense_units': 823, 'kernel_size': 3, 'pool_size': 3}
# Offsprings 4: {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 748, 'kernel_size': 6, 'pool_size': 2}
# Offsprings 5: {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 995, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 6: {'num_conv_layers': 4, 'num_filters': 2, 'num_dense_units': 814, 'kernel_size': 5, 'pool_size': 3}
# Offsprings 7: {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 620, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 8: {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 492, 'kernel_size': 4, 'pool_size': 3}
# Offsprings 9: {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 236, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 10: {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 1009, 'kernel_size': 5, 'pool_size': 2}
# ----------------------------------------------------------------------------------------------------------------------
# child fitness 1: 0.4950000047683716
# -------------------------------------------------------
# child fitness 2: 0.2612999975681305
# -------------------------------------------------------
# child fitness 3: 0.30889999866485596
# -------------------------------------------------------
# child fitness 4: 0.4099999964237213
# -------------------------------------------------------
# child fitness 5: 0.36230000853538513
# -------------------------------------------------------
# child fitness 6: 0.2754000127315521
# -------------------------------------------------------
# child fitness 7: 0.3912000060081482
# -------------------------------------------------------
# child fitness 8: 0.4611000120639801
# -------------------------------------------------------
# child fitness 9: 0.49410000443458557
# -------------------------------------------------------
# child fitness 10: 0.4334000051021576
# -------------------------------------------------------
# {'num_conv_layers': 6, 'num_filters': 8, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4950000047683716}
# {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.2612999975681305}
# {'num_conv_layers': 4, 'num_filters': 3, 'num_dense_units': 823, 'kernel_size': 3, 'pool_size': 3, 'fitness': 0.30889999866485596}
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 748, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4099999964237213}
# {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 995, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.36230000853538513}
# {'num_conv_layers': 4, 'num_filters': 2, 'num_dense_units': 814, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.2754000127315521}
# {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 620, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3912000060081482}
# {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 492, 'kernel_size': 4, 'pool_size': 3, 'fitness': 0.4611000120639801}
# {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 236, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.49410000443458557}
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 1009, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4334000051021576}
# ********************************generation: 5 **********************************************
# Select parents for reproduction
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 1009, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4334000051021576}
# {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 620, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3912000060081482}
# {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.2612999975681305}
# {'num_conv_layers': 6, 'num_filters': 8, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4950000047683716}
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 748, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4099999964237213}
# Generate offspring architectures using genetic operators:
# random choices parent1 and parent2 for offspring: 1
# parent1 {'num_conv_layers': 6, 'num_filters': 8, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4950000047683716}
# parent2 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 748, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4099999964237213}
# random choices parent1 and parent2 for offspring: 2
# parent1 {'num_conv_layers': 6, 'num_filters': 8, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4950000047683716}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.2612999975681305}
# random choices parent1 and parent2 for offspring: 3
# parent1 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 620, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3912000060081482}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.2612999975681305}
# Mutated kernel_size to 4
# random choices parent1 and parent2 for offspring: 4
# parent1 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.2612999975681305}
# parent2 {'num_conv_layers': 6, 'num_filters': 8, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4950000047683716}
# Mutated num_conv_layers to 4
# Mutated pool_size to 3
# random choices parent1 and parent2 for offspring: 5
# parent1 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 620, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3912000060081482}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.2612999975681305}
# Mutated num_conv_layers to 2
# Mutated pool_size to 4
# random choices parent1 and parent2 for offspring: 6
# parent1 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 1009, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4334000051021576}
# parent2 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 620, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3912000060081482}
# Mutated pool_size to 4
# random choices parent1 and parent2 for offspring: 7
# parent1 {'num_conv_layers': 6, 'num_filters': 8, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4950000047683716}
# parent2 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 748, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4099999964237213}
# Mutated num_conv_layers to 5
# Mutated num_filters to 2
# random choices parent1 and parent2 for offspring: 8
# parent1 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 748, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4099999964237213}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.2612999975681305}
# random choices parent1 and parent2 for offspring: 9
# parent1 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 1009, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4334000051021576}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.2612999975681305}
# random choices parent1 and parent2 for offspring: 10
# parent1 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 748, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.4099999964237213}
# parent2 {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.2612999975681305}
# Mutated kernel_size to 5
# ----------------------------------------------------------------------------------------------------------------------
# Offsprings 1: {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 760, 'kernel_size': 4, 'pool_size': 2}
# Offsprings 2: {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 3: {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 629, 'kernel_size': 4, 'pool_size': 2}
# Offsprings 4: {'num_conv_layers': 4, 'num_filters': 10, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 3}
# Offsprings 5: {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 632, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 6: {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 869, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 7: {'num_conv_layers': 5, 'num_filters': 2, 'num_dense_units': 740, 'kernel_size': 6, 'pool_size': 2}
# Offsprings 8: {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 7, 'pool_size': 2}
# Offsprings 9: {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 10: {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 737, 'kernel_size': 5, 'pool_size': 2}
# ----------------------------------------------------------------------------------------------------------------------
# child fitness 1: 0.4262000024318695
# -------------------------------------------------------
# child fitness 2: 0.4880000054836273
# -------------------------------------------------------
# child fitness 3: 0.093299999833107
# -------------------------------------------------------
# child fitness 4: 0.504800021648407
# -------------------------------------------------------
# child fitness 5: 0.2558000087738037
# -------------------------------------------------------
# child fitness 6: 0.2556000053882599
# -------------------------------------------------------
# child fitness 7: 0.2718999981880188
# -------------------------------------------------------
# child fitness 8: 0.093299999833107
# -------------------------------------------------------
# child fitness 9: 0.36880001425743103
# -------------------------------------------------------
# child fitness 10: 0.27070000767707825
# -------------------------------------------------------
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 760, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.4262000024318695}
# {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4880000054836273}
# {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 629, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.093299999833107}
# {'num_conv_layers': 4, 'num_filters': 10, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.504800021648407}
# {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 632, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.2558000087738037}
# {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 869, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.2556000053882599}
# {'num_conv_layers': 5, 'num_filters': 2, 'num_dense_units': 740, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.2718999981880188}
# {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 7, 'pool_size': 2, 'fitness': 0.093299999833107}
# {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.36880001425743103}
# {'num_conv_layers': 6, 'num_filters': 2, 'num_dense_units': 737, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.27070000767707825}
# ********************************generation: 6 **********************************************
# Select parents for reproduction
# {'num_conv_layers': 4, 'num_filters': 10, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.504800021648407}
# {'num_conv_layers': 5, 'num_filters': 2, 'num_dense_units': 740, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.2718999981880188}
# {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 629, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.093299999833107}
# {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.36880001425743103}
# {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4880000054836273}
# Generate offspring architectures using genetic operators:
# random choices parent1 and parent2 for offspring: 1
# parent1 {'num_conv_layers': 4, 'num_filters': 10, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.504800021648407}
# parent2 {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 629, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.093299999833107}
# Mutated num_conv_layers to 3
# Mutated num_filters to 11
# Mutated pool_size to 4
# random choices parent1 and parent2 for offspring: 2
# parent1 {'num_conv_layers': 4, 'num_filters': 10, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.504800021648407}
# parent2 {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4880000054836273}
# random choices parent1 and parent2 for offspring: 3
# parent1 {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 629, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.093299999833107}
# parent2 {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.36880001425743103}
# Mutated num_conv_layers to 2
# random choices parent1 and parent2 for offspring: 4
# parent1 {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 629, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.093299999833107}
# parent2 {'num_conv_layers': 4, 'num_filters': 10, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.504800021648407}
# Mutated kernel_size to 5
# Mutated pool_size to 2
# random choices parent1 and parent2 for offspring: 5
# parent1 {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4880000054836273}
# parent2 {'num_conv_layers': 5, 'num_filters': 2, 'num_dense_units': 740, 'kernel_size': 6, 'pool_size': 2, 'fitness': 0.2718999981880188}
# Mutated num_dense_units to 392
# Mutated kernel_size to 3
# random choices parent1 and parent2 for offspring: 6
# parent1 {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4880000054836273}
# parent2 {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.36880001425743103}
# Mutated kernel_size to 6
# random choices parent1 and parent2 for offspring: 7
# parent1 {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.36880001425743103}
# parent2 {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4880000054836273}
# Mutated num_conv_layers to 3
# random choices parent1 and parent2 for offspring: 8
# parent1 {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 629, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.093299999833107}
# parent2 {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.36880001425743103}
# random choices parent1 and parent2 for offspring: 9
# parent1 {'num_conv_layers': 4, 'num_filters': 10, 'num_dense_units': 754, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.504800021648407}
# parent2 {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.36880001425743103}
# Mutated num_conv_layers to 1
# random choices parent1 and parent2 for offspring: 10
# parent1 {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.36880001425743103}
# parent2 {'num_conv_layers': 7, 'num_filters': 2, 'num_dense_units': 629, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.093299999833107}
# Mutated kernel_size to 2
# ----------------------------------------------------------------------------------------------------------------------
# Offsprings 1: {'num_conv_layers': 3, 'num_filters': 11, 'num_dense_units': 629, 'kernel_size': 4, 'pool_size': 4}
# Offsprings 2: {'num_conv_layers': 6, 'num_filters': 10, 'num_dense_units': 755, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 3: {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 4: {'num_conv_layers': 4, 'num_filters': 10, 'num_dense_units': 627, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 5: {'num_conv_layers': 5, 'num_filters': 2, 'num_dense_units': 392, 'kernel_size': 3, 'pool_size': 2}
# Offsprings 6: {'num_conv_layers': 2, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 6, 'pool_size': 2}
# Offsprings 7: {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 8: {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 753, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 9: {'num_conv_layers': 1, 'num_filters': 10, 'num_dense_units': 755, 'kernel_size': 5, 'pool_size': 3}
# Offsprings 10: {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 2, 'pool_size': 2}
# ----------------------------------------------------------------------------------------------------------------------
# child fitness 1: 0.46149998903274536
# ...
# {'num_conv_layers': 1, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.3910999894142151}
# {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 929, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.4749000072479248}
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 441, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.40149998664855957}
# {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4106999933719635}
# {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 725, 'kernel_size': 4, 'pool_size': 4, 'fitness': 0.45210000872612}
# Generate offspring architectures using genetic operators:
# random choices parent1 and parent2 for offspring: 1
# parent1 {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 725, 'kernel_size': 4, 'pool_size': 4, 'fitness': 0.45210000872612}
# parent2 {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 929, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.4749000072479248}
# Mutated pool_size to 4
# random choices parent1 and parent2 for offspring: 2
# parent1 {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 725, 'kernel_size': 4, 'pool_size': 4, 'fitness': 0.45210000872612}
# parent2 {'num_conv_layers': 1, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.3910999894142151}
# Mutated num_conv_layers to 4
# Mutated num_filters to 13
# Mutated num_dense_units to 844
# random choices parent1 and parent2 for offspring: 3
# parent1 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4106999933719635}
# parent2 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 441, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.40149998664855957}
# random choices parent1 and parent2 for offspring: 4
# parent1 {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 929, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.4749000072479248}
# parent2 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 441, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.40149998664855957}
# Mutated num_dense_units to 889
# random choices parent1 and parent2 for offspring: 5
# parent1 {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 929, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.4749000072479248}
# parent2 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 441, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.40149998664855957}
# random choices parent1 and parent2 for offspring: 6
# parent1 {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 441, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.40149998664855957}
# parent2 {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 929, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.4749000072479248}
# Mutated num_conv_layers to 2
# Mutated pool_size to 4
# random choices parent1 and parent2 for offspring: 7
# parent1 {'num_conv_layers': 1, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.3910999894142151}
# parent2 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4106999933719635}
# random choices parent1 and parent2 for offspring: 8
# parent1 {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 929, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.4749000072479248}
# parent2 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4106999933719635}
# Mutated num_filters to 2
# Mutated kernel_size to 4
# random choices parent1 and parent2 for offspring: 9
# parent1 {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 725, 'kernel_size': 4, 'pool_size': 4, 'fitness': 0.45210000872612}
# parent2 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4106999933719635}
# random choices parent1 and parent2 for offspring: 10
# parent1 {'num_conv_layers': 1, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.3910999894142151}
# parent2 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4106999933719635}
# ----------------------------------------------------------------------------------------------------------------------
# Offsprings 1: {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 977, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 2: {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 844, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 3: {'num_conv_layers': 2, 'num_filters': 14, 'num_dense_units': 505, 'kernel_size': 5, 'pool_size': 3}
# Offsprings 4: {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 889, 'kernel_size': 5, 'pool_size': 3}
# Offsprings 5: {'num_conv_layers': 3, 'num_filters': 8, 'num_dense_units': 441, 'kernel_size': 5, 'pool_size': 3}
# Offsprings 6: {'num_conv_layers': 2, 'num_filters': 11, 'num_dense_units': 945, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 7: {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 8: {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2}
# Offsprings 9: {'num_conv_layers': 2, 'num_filters': 9, 'num_dense_units': 593, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 10: {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 4}
# ----------------------------------------------------------------------------------------------------------------------
# child fitness 1: 0.4855000078678131
# -------------------------------------------------------
# child fitness 2: 0.5273000001907349
# -------------------------------------------------------
# child fitness 3: 0.4659000039100647
# -------------------------------------------------------
# child fitness 4: 0.48080000281333923
# -------------------------------------------------------
# child fitness 5: 0.39410001039505005
# -------------------------------------------------------
# child fitness 6: 0.4465999901294708
# -------------------------------------------------------
# child fitness 7: 0.3736000061035156
# -------------------------------------------------------
# child fitness 8: 0.27410000562667847
# -------------------------------------------------------
# child fitness 9: 0.3517000079154968
# -------------------------------------------------------
# child fitness 10: 0.4691999852657318
# -------------------------------------------------------
# {'num_conv_layers': 3, 'num_filters': 9, 'num_dense_units': 977, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4855000078678131}
# {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 844, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.5273000001907349}
# {'num_conv_layers': 2, 'num_filters': 14, 'num_dense_units': 505, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.4659000039100647}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 889, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.48080000281333923}
# {'num_conv_layers': 3, 'num_filters': 8, 'num_dense_units': 441, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.39410001039505005}
# {'num_conv_layers': 2, 'num_filters': 11, 'num_dense_units': 945, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4465999901294708}
# {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3736000061035156}
# {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.27410000562667847}
# {'num_conv_layers': 2, 'num_filters': 9, 'num_dense_units': 593, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3517000079154968}
# {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4691999852657318}
# ********************************generation: 10 **********************************************
# Select parents for reproduction
# {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.27410000562667847}
# {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3736000061035156}
# {'num_conv_layers': 2, 'num_filters': 9, 'num_dense_units': 593, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3517000079154968}
# {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 844, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.5273000001907349}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 889, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.48080000281333923}
# Generate offspring architectures using genetic operators:
# random choices parent1 and parent2 for offspring: 1
# parent1 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3736000061035156}
# parent2 {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 844, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.5273000001907349}
# Mutated num_filters to 9
# random choices parent1 and parent2 for offspring: 2
# parent1 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3736000061035156}
# parent2 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 889, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.48080000281333923}
# Mutated num_dense_units to 822
# random choices parent1 and parent2 for offspring: 3
# parent1 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3736000061035156}
# parent2 {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 844, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.5273000001907349}
# random choices parent1 and parent2 for offspring: 4
# parent1 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.27410000562667847}
# parent2 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3736000061035156}
# Mutated pool_size to 3
# random choices parent1 and parent2 for offspring: 5
# parent1 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.27410000562667847}
# parent2 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3736000061035156}
# random choices parent1 and parent2 for offspring: 6
# parent1 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.27410000562667847}
# parent2 {'num_conv_layers': 2, 'num_filters': 9, 'num_dense_units': 593, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3517000079154968}
# random choices parent1 and parent2 for offspring: 7
# parent1 {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 889, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.48080000281333923}
# parent2 {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 844, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.5273000001907349}
# Mutated num_conv_layers to 6
# random choices parent1 and parent2 for offspring: 8
# parent1 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3736000061035156}
# parent2 {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 844, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.5273000001907349}
# Mutated num_conv_layers to 2
# random choices parent1 and parent2 for offspring: 9
# parent1 {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3736000061035156}
# parent2 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.27410000562667847}
# Mutated num_filters to 6
# random choices parent1 and parent2 for offspring: 10
# parent1 {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 844, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.5273000001907349}
# parent2 {'num_conv_layers': 3, 'num_filters': 2, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.27410000562667847}
# Mutated num_conv_layers to 6
# ----------------------------------------------------------------------------------------------------------------------
# Offsprings 1: {'num_conv_layers': 4, 'num_filters': 9, 'num_dense_units': 605, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 2: {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3}
# Offsprings 3: {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 836, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 4: {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 3}
# Offsprings 5: {'num_conv_layers': 2, 'num_filters': 9, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 6: {'num_conv_layers': 2, 'num_filters': 3, 'num_dense_units': 593, 'kernel_size': 5, 'pool_size': 2}
# Offsprings 7: {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 841, 'kernel_size': 5, 'pool_size': 7}
# Offsprings 8: {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 852, 'kernel_size': 5, 'pool_size': 4}
# Offsprings 9: {'num_conv_layers': 3, 'num_filters': 6, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2}
# Offsprings 10: {'num_conv_layers': 6, 'num_filters': 6, 'num_dense_units': 624, 'kernel_size': 5, 'pool_size': 2}
# ----------------------------------------------------------------------------------------------------------------------
# child fitness 1: 0.4666000008583069
# -------------------------------------------------------
# child fitness 2: 0.4999000132083893
# -------------------------------------------------------
# child fitness 3: 0.4970000088214874
# -------------------------------------------------------
# child fitness 4: 0.4650000035762787
# -------------------------------------------------------
# child fitness 5: 0.5031999945640564
# -------------------------------------------------------
# child fitness 6: 0.3391000032424927
# -------------------------------------------------------
# child fitness 7: 0.4099000096321106
# -------------------------------------------------------
# child fitness 8: 0.4828999936580658
# -------------------------------------------------------
# child fitness 9: 0.4546000063419342
# -------------------------------------------------------
# child fitness 10: 0.4041000008583069
# -------------------------------------------------------
# {'num_conv_layers': 4, 'num_filters': 9, 'num_dense_units': 605, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4666000008583069}
# {'num_conv_layers': 3, 'num_filters': 10, 'num_dense_units': 822, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.4999000132083893}
# {'num_conv_layers': 4, 'num_filters': 13, 'num_dense_units': 836, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4970000088214874}
# {'num_conv_layers': 2, 'num_filters': 10, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 3, 'fitness': 0.4650000035762787}
# {'num_conv_layers': 2, 'num_filters': 9, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.5031999945640564}
# {'num_conv_layers': 2, 'num_filters': 3, 'num_dense_units': 593, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.3391000032424927}
# {'num_conv_layers': 6, 'num_filters': 13, 'num_dense_units': 841, 'kernel_size': 5, 'pool_size': 7, 'fitness': 0.4099000096321106}
# {'num_conv_layers': 2, 'num_filters': 13, 'num_dense_units': 852, 'kernel_size': 5, 'pool_size': 4, 'fitness': 0.4828999936580658}
# {'num_conv_layers': 3, 'num_filters': 6, 'num_dense_units': 625, 'kernel_size': 4, 'pool_size': 2, 'fitness': 0.4546000063419342}
# {'num_conv_layers': 6, 'num_filters': 6, 'num_dense_units': 624, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.4041000008583069}
# Best architecture: {'num_conv_layers': 2, 'num_filters': 9, 'num_dense_units': 625, 'kernel_size': 5, 'pool_size': 2, 'fitness': 0.5031999945640564}
# evaluate test datse with Best architecture: 0.49619999527931213
